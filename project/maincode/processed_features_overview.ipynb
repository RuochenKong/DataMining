# %%
import pandas as pd
import numpy as np

# %%
Dnorm = pd.read_csv('../data/normalized.csv')
Dnorm.describe()
# Out:
#                beat       stft0_0       stft0_1       stft0_2       stft0_3  \
# count  19909.000000  19909.000000  19909.000000  19909.000000  19909.000000
# mean       0.419000      0.655034      0.956353      0.959120      0.959116
# std        0.101592      0.403256      0.094499      0.086923      0.087183
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.346154      0.000000      0.971728      0.975148      0.976170
# 50%        0.409091      0.885323      0.996199      0.996296      0.996380
# 75%        0.473684      0.958695      0.999434      0.999471      0.999460
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             stft0_4       stft0_5       stft0_6       stft0_7       stft0_8  \
# count  19909.000000  19909.000000  19909.000000  19909.000000  19909.000000
# mean       0.958958      0.959045      0.960455      0.959870      0.960356
# ...

# %%
Dorigin = pd.read_csv('../data/processed_train.csv')
Dorigin.describe()
# Out:
#                beat       stft0_0       stft0_1       stft0_2       stft0_3  \
# count  19909.000000  19909.000000  19909.000000  19909.000000  19909.000000
# mean     120.298900      0.655034      0.956353      0.959120      0.959116
# std       29.168129      0.403256      0.094499      0.086923      0.087183
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       99.384014      0.000000      0.971728      0.975148      0.976170
# 50%      117.453835      0.885323      0.996199      0.996296      0.996380
# 75%      135.999178      0.958695      0.999434      0.999471      0.999460
# max      287.109375      1.000000      1.000000      1.000000      1.000000
#
#             stft0_4       stft0_5       stft0_6       stft0_7       stft0_8  \
# count  19909.000000  19909.000000  19909.000000  19909.000000  19909.000000
# mean       0.958958      0.959045      0.960455      0.959870      0.960356
# ...

# %%
Dfilter = pd.read_csv('../data/norm_filtcorr.csv')
Dfilter.describe()
# Out:
#                beat       stft0_0       stft0_1       stft0_2       stft0_3  \
# count  19909.000000  19909.000000  19909.000000  19909.000000  19909.000000
# mean       0.419000      0.655034      0.956353      0.959120      0.959116
# std        0.101592      0.403256      0.094499      0.086923      0.087183
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.346154      0.000000      0.971728      0.975148      0.976170
# 50%        0.409091      0.885323      0.996199      0.996296      0.996380
# 75%        0.473684      0.958695      0.999434      0.999471      0.999460
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             stft0_4       stft0_5       stft0_6       stft0_7       stft0_8  \
# count  19909.000000  19909.000000  19909.000000  19909.000000  19909.000000
# mean       0.958958      0.959045      0.960455      0.959870      0.960356
# ...
